# %%
import pandas as pd
import json

# %%
hcpcs_mapping = pd.read_csv("/Users/sarvesh/Downloads/HCPCS Mapping.csv")
doc_mapping = pd.read_csv("/Users/sarvesh/Downloads/Doc Mapping.csv")
hcpcs_raw_data = pd.read_csv("/Users/sarvesh/Downloads/HCPCS Raw Data.csv")

# %%
hcpcs_mapping
# Out:
#    HCPCS Code                                    HCPCS Desc  \
# 0       93010  Electrocardiogram (Ecg/Ekg) Hospital Reading
#
#                                      HCPCS Group HCPCS Class  \
# 0  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
#
#         HCPCS Subclass HCPCS Subsubclass
# 0  Clinical Cardiology        Diagnostic

# %%
doc_mapping
# Out:
#          NPI_DOC           PFNAME      PLNAME     NPI_ORG  \
# 0     1740569227    MOHAMED FAHER   ALMAHMOUD  1487669248
# 1     1578558987            DAVID      HECTOR  1609382662
# 2     1598074528            SWATI    CHOUDHRY  1861675506
# 3     1558556001            JOGGY      GEORGE  1851516272
# 4     1174529325            MIKKO  TAURIAINEN  1457651606
# ...          ...              ...         ...         ...
# 2183  1881861771          MIHAELA      KRUGER  1689984585
# 2184  1932294469          SARITHA       DODLA  1578904512
# 2185  1467683847  ARUN SRINIVASAN      KANNAN  1033157821
# 2186  1437395415            SELBY     OBERTON  1881026664
# 2187  1366457921            POYEE        TUNG  1033157821
#
#                                          ORG_NAME  \
# 0       LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 1                       ETMC PHYSICIAN GROUP INC.
# 2                TEXAS CHILDREN'S PHYSICIAN GROUP
# 3                       CARDIOLOGY ASSOCIATES P.A
# 4          NORTH TEXAS HEART SURGERY CENTER, PLLC
# ...                                           ...
# 2183  CARDIOLOGY SPECIALISTS OF NORTH TEXAS, PLLC
# 2184                      EXCEL CARDIAC CARE PLLC
# 2185                                UT PHYSICIANS
# 2186                   BAYLOR COLLEGE OF MEDICINE
# 2187                                UT PHYSICIANS
#
#                                           DOC_SPECIALTY    DOC_CITY  \
# 0                      Cardiovascular Disease Physician    KINGWOOD
# 1                   Interventional Cardiology Physician       TYLER
# 2                        Pediatric Cardiology Physician     HOUSTON
# 3                      Cardiovascular Disease Physician     HOUSTON
# 4     Thoracic Surgery (Cardiothoracic Vascular Surg...       PLANO
# ...                                                 ...         ...
# 2183                Interventional Cardiology Physician   MANSFIELD
# 2184                   Cardiovascular Disease Physician  FORT WORTH
# 2185       Clinical Cardiac Electrophysiology Physician     HOUSTON
# 2186                   Cardiovascular Disease Physician     HOUSTON
# 2187                   Cardiovascular Disease Physician     HOUSTON
#
#      DOC_COUNTY DOC_STATE  DOC_ZIP
# 0       Harris         TX    77339
# 1        Smith         TX    75701
# 2       Harris         TX    77030
# 3       Harris         TX    77030
# 4       Collin         TX    75093
# ...         ...       ...      ...
# 2183   Tarrant         TX    76063
# 2184   Tarrant         TX    76244
# 2185    Harris         TX    77030
# 2186    Harris         TX    77030
# 2187    Harris         TX    77030
#
# [2188 rows x 10 columns]

# %%
hcpcs_raw_data.head()
# Out:
#    Year  HCPCS Code     NPI_DOC  SRVS_ASC_PHY  SRVS_IP_PHY  SRVS_OFF  \
# 0  2019       93010  1740398577           NaN         41.0       NaN
# 1  2020       93010  1184678310           NaN        513.0       NaN
# 2  2019       93010  1184678310           NaN        827.0       NaN
# 3  2021       93010  1184678310           NaN        450.0       NaN
# 4  2020       93010  1821089285           NaN         89.0       NaN
#
#    SRVS_OP_PHY  ALWD_ASC_PHY  ALWD_IP_PHY  ALWD_OFF  ALWD_OP_PHY  \
# 0         35.0           NaN       342.22       NaN       284.46
# 1        254.0           NaN      4282.84       NaN      1669.14
# 2        409.0           NaN      6823.48       NaN      3073.81
# 3        161.0           NaN      3601.59       NaN      1056.90
# 4         28.0           NaN       764.72       NaN       243.32
#
#    PAID_ASC_PHY  PAID_IP_PHY  PAID_OFF  PAID_OP_PHY
# 0           NaN       266.00       NaN       226.80
# 1           NaN      3453.53       NaN      1338.39
# 2           NaN      5400.80       NaN      2432.92
# 3           NaN      2912.78       NaN       856.70
# 4           NaN       609.50       NaN       194.46

# %%
# ---------------

# %%
# NPI_DOC,PFNAME,ORG_NAME,DOC_SPECIALTY,DOC_CITY,DOC_STATE,SRVS_ASC_PHY,SRVS_IP_PHY,SRVS_OFF,SRVS_OP_PHY

# %%
combined_df = doc_mapping.merge(hcpcs_raw_data,how='inner',left_on='NPI_DOC',right_on='NPI_DOC',suffixes=['_doc_mapping,','hcpcs_raw_data'])                                                      

combined_df
# Out:
#          NPI_DOC         PFNAME     PLNAME     NPI_ORG  \
# 0     1740569227  MOHAMED FAHER  ALMAHMOUD  1487669248
# 1     1740569227  MOHAMED FAHER  ALMAHMOUD  1487669248
# 2     1578558987          DAVID     HECTOR  1609382662
# 3     1578558987          DAVID     HECTOR  1609382662
# 4     1578558987          DAVID     HECTOR  1609382662
# ...          ...            ...        ...         ...
# 3447  1437395415          SELBY    OBERTON  1881026664
# 3448  1437395415          SELBY    OBERTON  1881026664
# 3449  1366457921          POYEE       TUNG  1033157821
# 3450  1366457921          POYEE       TUNG  1033157821
# 3451  1366457921          POYEE       TUNG  1033157821
#
#                                        ORG_NAME  \
# 0     LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 1     LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 2                     ETMC PHYSICIAN GROUP INC.
# 3                     ETMC PHYSICIAN GROUP INC.
# 4                     ETMC PHYSICIAN GROUP INC.
# ...                                         ...
# 3447                 BAYLOR COLLEGE OF MEDICINE
# 3448                 BAYLOR COLLEGE OF MEDICINE
# 3449                              UT PHYSICIANS
# 3450                              UT PHYSICIANS
# 3451                              UT PHYSICIANS
#
#                             DOC_SPECIALTY  DOC_CITY DOC_COUNTY DOC_STATE  \
# 0        Cardiovascular Disease Physician  KINGWOOD    Harris         TX
# 1        Cardiovascular Disease Physician  KINGWOOD    Harris         TX
# 2     Interventional Cardiology Physician     TYLER     Smith         TX
# 3     Interventional Cardiology Physician     TYLER     Smith         TX
# 4     Interventional Cardiology Physician     TYLER     Smith         TX
# ...                                   ...       ...        ...       ...
# 3447     Cardiovascular Disease Physician   HOUSTON    Harris         TX
# 3448     Cardiovascular Disease Physician   HOUSTON    Harris         TX
# 3449     Cardiovascular Disease Physician   HOUSTON    Harris         TX
# 3450     Cardiovascular Disease Physician   HOUSTON    Harris         TX
# 3451     Cardiovascular Disease Physician   HOUSTON    Harris         TX
#
#       DOC_ZIP  ...  SRVS_OFF  SRVS_OP_PHY  ALWD_ASC_PHY  ALWD_IP_PHY  \
# 0       77339  ...       NaN          5.0           NaN       101.16
# 1       77339  ...       NaN         74.0           NaN      1662.79
# 2       75701  ...       3.0        513.0           NaN      3549.03
# 3       75701  ...       3.0        506.0           NaN      3046.84
# 4       75701  ...       NaN        393.0           NaN      2341.44
# ...       ...  ...       ...          ...           ...          ...
# 3447    77030  ...       NaN         36.0           NaN        61.39
# 3448    77030  ...       NaN          8.0           NaN          NaN
# 3449    77030  ...       NaN         58.0           NaN      1139.07
# 3450    77030  ...       NaN         31.0           NaN       903.31
# 3451    77030  ...       NaN         24.0           NaN      1005.03
#
#       ALWD_OFF  ALWD_OP_PHY  PAID_ASC_PHY  PAID_IP_PHY  PAID_OFF  PAID_OP_PHY
# 0          NaN        33.72           NaN        80.88       NaN        26.96
# 1          NaN       588.88           NaN      1329.71       NaN       464.04
# 2        16.86      4223.43           NaN      2805.09     13.66      3243.30
# 3        16.88      4186.24           NaN      2353.92     13.42      3105.02
# 4          NaN      3138.18           NaN      1867.59       NaN      2461.46
# ...        ...          ...           ...          ...       ...          ...
# 3447       NaN       324.49           NaN        48.72       NaN       222.70
# 3448       NaN        60.13           NaN          NaN       NaN        48.79
# 3449       NaN       503.31           NaN       917.53       NaN       401.84
# 3450       NaN       228.02           NaN       716.88       NaN       180.96
# 3451       NaN       206.16           NaN       804.96       NaN       165.12
#
# [3452 rows x 24 columns]

# %%
final_df = combined_df[["NPI_DOC",
"PFNAME",
"ORG_NAME",
"DOC_SPECIALTY",
"DOC_CITY",
"DOC_STATE",
"SRVS_ASC_PHY","SRVS_IP_PHY","SRVS_OFF","SRVS_OP_PHY","HCPCS Code"]]

# %%
final_df
# Out:
#          NPI_DOC         PFNAME                                   ORG_NAME  \
# 0     1740569227  MOHAMED FAHER  LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 1     1740569227  MOHAMED FAHER  LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 2     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# 3     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# 4     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# ...          ...            ...                                        ...
# 3447  1437395415          SELBY                 BAYLOR COLLEGE OF MEDICINE
# 3448  1437395415          SELBY                 BAYLOR COLLEGE OF MEDICINE
# 3449  1366457921          POYEE                              UT PHYSICIANS
# 3450  1366457921          POYEE                              UT PHYSICIANS
# 3451  1366457921          POYEE                              UT PHYSICIANS
#
#                             DOC_SPECIALTY  DOC_CITY DOC_STATE  SRVS_ASC_PHY  \
# 0        Cardiovascular Disease Physician  KINGWOOD        TX           NaN
# 1        Cardiovascular Disease Physician  KINGWOOD        TX           NaN
# 2     Interventional Cardiology Physician     TYLER        TX           NaN
# 3     Interventional Cardiology Physician     TYLER        TX           NaN
# 4     Interventional Cardiology Physician     TYLER        TX           NaN
# ...                                   ...       ...       ...           ...
# 3447     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3448     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3449     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3450     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3451     Cardiovascular Disease Physician   HOUSTON        TX           NaN
#
#       SRVS_IP_PHY  SRVS_OFF  SRVS_OP_PHY  HCPCS Code
# 0            14.0       NaN          5.0       93010
# 1           207.0       NaN         74.0       93010
# 2           432.0       3.0        513.0       93010
# 3           367.0       3.0        506.0       93010
# 4           325.0       NaN        393.0       93010
# ...           ...       ...          ...         ...
# 3447          8.0       NaN         36.0       93010
# 3448          NaN       NaN          8.0       93010
# 3449        133.0       NaN         58.0       93010
# 3450        109.0       NaN         31.0       93010
# 3451        121.0       NaN         24.0       93010
#
# [3452 rows x 11 columns]

# %%
final_df_with_hcpcs=final_df.merge(hcpcs_mapping,how='inner',left_on='HCPCS Code',right_on='HCPCS Code',suffixes=['_final_df','_hcpcs_mapping'])
final_df_with_hcpcs
# Out:
#          NPI_DOC         PFNAME                                   ORG_NAME  \
# 0     1740569227  MOHAMED FAHER  LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 1     1740569227  MOHAMED FAHER  LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 2     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# 3     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# 4     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# ...          ...            ...                                        ...
# 3447  1437395415          SELBY                 BAYLOR COLLEGE OF MEDICINE
# 3448  1437395415          SELBY                 BAYLOR COLLEGE OF MEDICINE
# 3449  1366457921          POYEE                              UT PHYSICIANS
# 3450  1366457921          POYEE                              UT PHYSICIANS
# 3451  1366457921          POYEE                              UT PHYSICIANS
#
#                             DOC_SPECIALTY  DOC_CITY DOC_STATE  SRVS_ASC_PHY  \
# 0        Cardiovascular Disease Physician  KINGWOOD        TX           NaN
# 1        Cardiovascular Disease Physician  KINGWOOD        TX           NaN
# 2     Interventional Cardiology Physician     TYLER        TX           NaN
# 3     Interventional Cardiology Physician     TYLER        TX           NaN
# 4     Interventional Cardiology Physician     TYLER        TX           NaN
# ...                                   ...       ...       ...           ...
# 3447     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3448     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3449     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3450     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3451     Cardiovascular Disease Physician   HOUSTON        TX           NaN
#
#       SRVS_IP_PHY  SRVS_OFF  SRVS_OP_PHY  HCPCS Code  \
# 0            14.0       NaN          5.0       93010
# 1           207.0       NaN         74.0       93010
# 2           432.0       3.0        513.0       93010
# 3           367.0       3.0        506.0       93010
# 4           325.0       NaN        393.0       93010
# ...           ...       ...          ...         ...
# 3447          8.0       NaN         36.0       93010
# 3448          NaN       NaN          8.0       93010
# 3449        133.0       NaN         58.0       93010
# 3450        109.0       NaN         31.0       93010
# 3451        121.0       NaN         24.0       93010
#
#                                         HCPCS Desc  \
# 0     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 1     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 2     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 4     Electrocardiogram (Ecg/Ekg) Hospital Reading
# ...                                            ...
# 3447  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3448  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3449  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3450  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3451  Electrocardiogram (Ecg/Ekg) Hospital Reading
#
#                                         HCPCS Group HCPCS Class  \
# 0     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 1     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 2     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 4     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# ...                                             ...         ...
# 3447  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3448  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3449  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3450  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3451  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
#
#            HCPCS Subclass HCPCS Subsubclass
# 0     Clinical Cardiology        Diagnostic
# 1     Clinical Cardiology        Diagnostic
# 2     Clinical Cardiology        Diagnostic
# 3     Clinical Cardiology        Diagnostic
# 4     Clinical Cardiology        Diagnostic
# ...                   ...               ...
# 3447  Clinical Cardiology        Diagnostic
# 3448  Clinical Cardiology        Diagnostic
# 3449  Clinical Cardiology        Diagnostic
# 3450  Clinical Cardiology        Diagnostic
# 3451  Clinical Cardiology        Diagnostic
#
# [3452 rows x 16 columns]

# %%
final_df_with_hcpcs.columns = final_df_with_hcpcs.columns.str.replace(' ', '_')
# final_df_with_hcpcs.query()

# %%
request = {
    "HCPCS_Class":["Cardiology"],
    "HCPCS_Subclass":["Clinical Cardiology"]
}

ls = [(k,v) for k,v in request.items()]
queries=[]
for item in ls:
    query = f"{item[0]} in {item[1]}"
    queries.append(query)

# %%
final_query=" & ".join(queries)
final_query
# Out:
# "HCPCS_Class in ['Cardiology'] & HCPCS_Subclass in ['Clinical Cardiology']"

# %%
final_df_with_hcpcs.query(final_query)
# Out:
#          NPI_DOC         PFNAME                                   ORG_NAME  \
# 0     1740569227  MOHAMED FAHER  LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 1     1740569227  MOHAMED FAHER  LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA
# 2     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# 3     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# 4     1578558987          DAVID                  ETMC PHYSICIAN GROUP INC.
# ...          ...            ...                                        ...
# 3447  1437395415          SELBY                 BAYLOR COLLEGE OF MEDICINE
# 3448  1437395415          SELBY                 BAYLOR COLLEGE OF MEDICINE
# 3449  1366457921          POYEE                              UT PHYSICIANS
# 3450  1366457921          POYEE                              UT PHYSICIANS
# 3451  1366457921          POYEE                              UT PHYSICIANS
#
#                             DOC_SPECIALTY  DOC_CITY DOC_STATE  SRVS_ASC_PHY  \
# 0        Cardiovascular Disease Physician  KINGWOOD        TX           NaN
# 1        Cardiovascular Disease Physician  KINGWOOD        TX           NaN
# 2     Interventional Cardiology Physician     TYLER        TX           NaN
# 3     Interventional Cardiology Physician     TYLER        TX           NaN
# 4     Interventional Cardiology Physician     TYLER        TX           NaN
# ...                                   ...       ...       ...           ...
# 3447     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3448     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3449     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3450     Cardiovascular Disease Physician   HOUSTON        TX           NaN
# 3451     Cardiovascular Disease Physician   HOUSTON        TX           NaN
#
#       SRVS_IP_PHY  SRVS_OFF  SRVS_OP_PHY  HCPCS_Code  \
# 0            14.0       NaN          5.0       93010
# 1           207.0       NaN         74.0       93010
# 2           432.0       3.0        513.0       93010
# 3           367.0       3.0        506.0       93010
# 4           325.0       NaN        393.0       93010
# ...           ...       ...          ...         ...
# 3447          8.0       NaN         36.0       93010
# 3448          NaN       NaN          8.0       93010
# 3449        133.0       NaN         58.0       93010
# 3450        109.0       NaN         31.0       93010
# 3451        121.0       NaN         24.0       93010
#
#                                         HCPCS_Desc  \
# 0     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 1     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 2     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3     Electrocardiogram (Ecg/Ekg) Hospital Reading
# 4     Electrocardiogram (Ecg/Ekg) Hospital Reading
# ...                                            ...
# 3447  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3448  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3449  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3450  Electrocardiogram (Ecg/Ekg) Hospital Reading
# 3451  Electrocardiogram (Ecg/Ekg) Hospital Reading
#
#                                         HCPCS_Group HCPCS_Class  \
# 0     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 1     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 2     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 4     Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# ...                                             ...         ...
# 3447  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3448  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3449  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3450  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
# 3451  Cardiology - Clinical Cardiology - Diagnostic  Cardiology
#
#            HCPCS_Subclass HCPCS_Subsubclass
# 0     Clinical Cardiology        Diagnostic
# 1     Clinical Cardiology        Diagnostic
# 2     Clinical Cardiology        Diagnostic
# 3     Clinical Cardiology        Diagnostic
# 4     Clinical Cardiology        Diagnostic
# ...                   ...               ...
# 3447  Clinical Cardiology        Diagnostic
# 3448  Clinical Cardiology        Diagnostic
# 3449  Clinical Cardiology        Diagnostic
# 3450  Clinical Cardiology        Diagnostic
# 3451  Clinical Cardiology        Diagnostic
#
# [3452 rows x 16 columns]

# %%
final_df_with_hcpcs.groupby(['NPI_DOC','PFNAME','ORG_NAME','DOC_SPECIALTY','DOC_CITY','DOC_STATE']).sum()
# Out:
#                                                                                                                                               SRVS_ASC_PHY  \
# NPI_DOC    PFNAME    ORG_NAME                                           DOC_SPECIALTY                                DOC_CITY      DOC_STATE
# 1003080375 ASHESH    TEXAS HEALTH PHYSICIANS GROUP                      Cardiovascular Disease Physician             PLANO         TX                  0.0
# 1003081308 GREGORY   COOK CHILDREN'S PHYSICIAN NETWORK                  Pediatric Cardiology Physician               FORT WORTH    TX                  0.0
# 1003174954 ALVIN     UNIVERSITY OF TEXAS SOUTHWESTERN MEDICAL CENTER... Cardiovascular Disease Physician             DALLAS        TX                  0.0
# 1003217522 SRIKANTH  BAYLOR COLLEGE OF MEDICINE                         Cardiovascular Disease Physician             HOUSTON       TX                  0.0
# 1003801705 STANISLAV CHRISTUS TRINITY CLINIC                            Clinical Cardiac Electrophysiology Physician TYLER         TX                  0.0
# ...                                                                                                                                                    ...
# 1992777320 KIRAN     CARDIOLOGY CLINIC OF SAN ANTONIO, PLLC             Clinical Cardiac Electrophysiology Physician SAN ANTONIO   TX                  0.0
# 1992880595 GEORGE    NASSER CARDIOLOGY, P.A.                            Cardiovascular Disease Physician             THE WOODLANDS TX                 10.0
# 1992913933 SAM       CHRISTUS TRINITY CLINIC                            Cardiovascular Disease Physician             MARSHALL      TX                  0.0
# 1992931133 ROBERT    CARDIOVASCULAR ASSOCIATION, P.L.L.C                Cardiovascular Disease Physician             HUMBLE        TX                  0.0
# 1992944433 JEAN      ADENA MEDICAL GROUP LLC                            Cardiovascular Disease Physician             HOUSTON       TX                  0.0
#
#                                                                                                                                               SRVS_IP_PHY  \
# NPI_DOC    PFNAME    ORG_NAME                                           DOC_SPECIALTY                                DOC_CITY      DOC_STATE
# 1003080375 ASHESH    TEXAS HEALTH PHYSICIANS GROUP                      Cardiovascular Disease Physician             PLANO         TX               277.0
# 1003081308 GREGORY   COOK CHILDREN'S PHYSICIAN NETWORK                  Pediatric Cardiology Physician               FORT WORTH    TX                 4.0
# 1003174954 ALVIN     UNIVERSITY OF TEXAS SOUTHWESTERN MEDICAL CENTER... Cardiovascular Disease Physician             DALLAS        TX               269.0
# 1003217522 SRIKANTH  BAYLOR COLLEGE OF MEDICINE                         Cardiovascular Disease Physician             HOUSTON       TX               363.0
# 1003801705 STANISLAV CHRISTUS TRINITY CLINIC                            Clinical Cardiac Electrophysiology Physician TYLER         TX               261.0
# ...                                                                                                                                                   ...
# 1992777320 KIRAN     CARDIOLOGY CLINIC OF SAN ANTONIO, PLLC             Clinical Cardiac Electrophysiology Physician SAN ANTONIO   TX               525.0
# 1992880595 GEORGE    NASSER CARDIOLOGY, P.A.                            Cardiovascular Disease Physician             THE WOODLANDS TX                 0.0
# 1992913933 SAM       CHRISTUS TRINITY CLINIC                            Cardiovascular Disease Physician             MARSHALL      TX               157.0
# 1992931133 ROBERT    CARDIOVASCULAR ASSOCIATION, P.L.L.C                Cardiovascular Disease Physician             HUMBLE        TX               284.0
# 1992944433 JEAN      ADENA MEDICAL GROUP LLC                            Cardiovascular Disease Physician             HOUSTON       TX               274.0
#
#                                                                                                                                               SRVS_OFF  \
# NPI_DOC    PFNAME    ORG_NAME                                           DOC_SPECIALTY                                DOC_CITY      DOC_STATE
# 1003080375 ASHESH    TEXAS HEALTH PHYSICIANS GROUP                      Cardiovascular Disease Physician             PLANO         TX             12.0
# 1003081308 GREGORY   COOK CHILDREN'S PHYSICIAN NETWORK                  Pediatric Cardiology Physician               FORT WORTH    TX              0.0
# 1003174954 ALVIN     UNIVERSITY OF TEXAS SOUTHWESTERN MEDICAL CENTER... Cardiovascular Disease Physician             DALLAS        TX             15.0
# 1003217522 SRIKANTH  BAYLOR COLLEGE OF MEDICINE                         Cardiovascular Disease Physician             HOUSTON       TX              0.0
# 1003801705 STANISLAV CHRISTUS TRINITY CLINIC                            Clinical Cardiac Electrophysiology Physician TYLER         TX            228.0
# ...                                                                                                                                                ...
# 1992777320 KIRAN     CARDIOLOGY CLINIC OF SAN ANTONIO, PLLC             Clinical Cardiac Electrophysiology Physician SAN ANTONIO   TX              2.0
# 1992880595 GEORGE    NASSER CARDIOLOGY, P.A.                            Cardiovascular Disease Physician             THE WOODLANDS TX              0.0
# 1992913933 SAM       CHRISTUS TRINITY CLINIC                            Cardiovascular Disease Physician             MARSHALL      TX             12.0
# 1992931133 ROBERT    CARDIOVASCULAR ASSOCIATION, P.L.L.C                Cardiovascular Disease Physician             HUMBLE        TX              0.0
# 1992944433 JEAN      ADENA MEDICAL GROUP LLC                            Cardiovascular Disease Physician             HOUSTON       TX              0.0
#
#                                                                                                                                               SRVS_OP_PHY  \
# NPI_DOC    PFNAME    ORG_NAME                                           DOC_SPECIALTY                                DOC_CITY      DOC_STATE
# 1003080375 ASHESH    TEXAS HEALTH PHYSICIANS GROUP                      Cardiovascular Disease Physician             PLANO         TX               167.0
# 1003081308 GREGORY   COOK CHILDREN'S PHYSICIAN NETWORK                  Pediatric Cardiology Physician               FORT WORTH    TX                 6.0
# 1003174954 ALVIN     UNIVERSITY OF TEXAS SOUTHWESTERN MEDICAL CENTER... Cardiovascular Disease Physician             DALLAS        TX               185.0
# 1003217522 SRIKANTH  BAYLOR COLLEGE OF MEDICINE                         Cardiovascular Disease Physician             HOUSTON       TX               214.0
# 1003801705 STANISLAV CHRISTUS TRINITY CLINIC                            Clinical Cardiac Electrophysiology Physician TYLER         TX              6441.0
# ...                                                                                                                                                   ...
# 1992777320 KIRAN     CARDIOLOGY CLINIC OF SAN ANTONIO, PLLC             Clinical Cardiac Electrophysiology Physician SAN ANTONIO   TX               170.0
# 1992880595 GEORGE    NASSER CARDIOLOGY, P.A.                            Cardiovascular Disease Physician             THE WOODLANDS TX                 0.0
# 1992913933 SAM       CHRISTUS TRINITY CLINIC                            Cardiovascular Disease Physician             MARSHALL      TX               449.0
# 1992931133 ROBERT    CARDIOVASCULAR ASSOCIATION, P.L.L.C                Cardiovascular Disease Physician             HUMBLE        TX               150.0
# 1992944433 JEAN      ADENA MEDICAL GROUP LLC                            Cardiovascular Disease Physician             HOUSTON       TX               404.0
#
#                                                                                                                                               HCPCS_Code
# NPI_DOC    PFNAME    ORG_NAME                                           DOC_SPECIALTY                                DOC_CITY      DOC_STATE
# 1003080375 ASHESH    TEXAS HEALTH PHYSICIANS GROUP                      Cardiovascular Disease Physician             PLANO         TX             279030
# 1003081308 GREGORY   COOK CHILDREN'S PHYSICIAN NETWORK                  Pediatric Cardiology Physician               FORT WORTH    TX             279030
# 1003174954 ALVIN     UNIVERSITY OF TEXAS SOUTHWESTERN MEDICAL CENTER... Cardiovascular Disease Physician             DALLAS        TX             279030
# 1003217522 SRIKANTH  BAYLOR COLLEGE OF MEDICINE                         Cardiovascular Disease Physician             HOUSTON       TX             279030
# 1003801705 STANISLAV CHRISTUS TRINITY CLINIC                            Clinical Cardiac Electrophysiology Physician TYLER         TX             279030
# ...                                                                                                                                                  ...
# 1992777320 KIRAN     CARDIOLOGY CLINIC OF SAN ANTONIO, PLLC             Clinical Cardiac Electrophysiology Physician SAN ANTONIO   TX             279030
# 1992880595 GEORGE    NASSER CARDIOLOGY, P.A.                            Cardiovascular Disease Physician             THE WOODLANDS TX             279030
# 1992913933 SAM       CHRISTUS TRINITY CLINIC                            Cardiovascular Disease Physician             MARSHALL      TX             186020
# 1992931133 ROBERT    CARDIOVASCULAR ASSOCIATION, P.L.L.C                Cardiovascular Disease Physician             HUMBLE        TX             279030
# 1992944433 JEAN      ADENA MEDICAL GROUP LLC                            Cardiovascular Disease Physician             HOUSTON       TX             279030
#
# [1404 rows x 5 columns]

# %%
final_op=final_df_with_hcpcs.groupby(['NPI_DOC','PFNAME','ORG_NAME','DOC_SPECIALTY','DOC_CITY','DOC_STATE']).sum().reset_index()
final_op.dtypes
# Out:
# NPI_DOC            int64
# PFNAME            object
# ORG_NAME          object
# DOC_SPECIALTY     object
# DOC_CITY          object
# DOC_STATE         object
# SRVS_ASC_PHY     float64
# SRVS_IP_PHY      float64
# SRVS_OFF         float64
# SRVS_OP_PHY      float64
# HCPCS_Code         int64
# dtype: object

# %%
aggregated_op=[]
for index,row in final_op.iterrows():
    result = {
        'Physician NPI':row['NPI_DOC'],
        'Physician':row['PFNAME'],
        'Org Name': row['ORG_NAME'],
        'Speciality':row['DOC_SPECIALTY'],
        'City':row['DOC_CITY'],
        'State':row['DOC_STATE'],
        'ASC':row['SRVS_ASC_PHY'],
        'IP':row['SRVS_IP_PHY'],
        'OP':row['SRVS_OP_PHY'],
        'OFFICE':row['SRVS_OFF'],
        'Total': sum([row['SRVS_ASC_PHY'],row['SRVS_IP_PHY'],row['SRVS_OP_PHY'],row['SRVS_OFF']])
    }
    aggregated_op.append(result)

# %%
response = json.dumps(aggregated_op,indent=2)

# %%
response
# Out:
# '[\n  {\n    "Physician NPI": 1578558987,\n    "Physician": "DAVID",\n    "Org Name": "ETMC PHYSICIAN GROUP INC.",\n    "Speciality": "Interventional Cardiology Physician",\n    "City": "TYLER",\n    "State": "TX",\n    "ASC": 0.0,\n    "IP": 1124.0,\n    "OP": 1412.0,\n    "OFFICE": 6.0,\n    "Total": 2542.0\n  },\n  {\n    "Physician NPI": 1740569227,\n    "Physician": "MOHAMED FAHER",\n    "Org Name": "LIEBER AND MOORE CARDIOLOGY ASSOCIATES PA",\n    "Speciality": "Cardiovascular Disease Physician",\n    "City": "KINGWOOD",\n    "State": "TX",\n    "ASC": 0.0,\n    "IP": 221.0,\n    "OP": 79.0,\n    "OFFICE": 0.0,\n    "Total": 300.0\n  }\n]'

# %%
# 1. Filter df with UI filters
# 2. Group by final_df_with_hcpcs.groupby(['NPI_DOC','PFNAME','ORG_NAME','DOC_SPECIALTY','DOC_CITY','DOC_STATE']).sum()
